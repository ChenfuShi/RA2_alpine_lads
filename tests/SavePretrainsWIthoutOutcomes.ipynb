# %%
import os

os.chdir('/mnt/jw01-aruk-home01/projects/ra_challenge/RA_challenge/michael_dev/RA2_alpine_lads/ra_joint_predictions')

# %%
from utils.config import Config

config = Config()

# %%
from model.RSNA_model import create_rsna_NASnet_multioutupt

model = create_rsna_NASnet_multioutupt(config)

# %%
model.load_weights('./weights/rsna_multioutput_NASnet_pretrain_model_490')

# %%
from utils.saver import save_pretrained_model

save_pretrained_model(model, 15, 'complex_rsna_pretrain_v1')

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('complex_rsna_pretrain_v1.h5')
# Out:
# 2020-02-28 13:52:49,431;WARNING - No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
from tensorflow.keras.utils import plot_model

plot_model(loaded_model)
