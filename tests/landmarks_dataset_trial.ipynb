# %%
import os

PATH = 'C:\\Users\\CrankMuffler\\Documents\\GitHub\\RA2_alpine_lads'

os.chdir(PATH)

# %%
from utils.config import Config

config = Config()

# %%
from dataset.landmarks_dataset import feet_landmarks_dataset

landmark_dataset = feet_landmarks_dataset(config).create_landmarks_dataset()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c9ab83714d08> in <module>
# ----> 1 from dataset.landmarks_dataset import feet_landmarks_dataset
#       2
#       3 landmark_dataset = feet_landmarks_dataset(config).create_landmarks_dataset()
#
# ~\Documents\GitHub\RA2_alpine_lads\dataset\landmarks_dataset.py in <module>
#       6 import tensorflow as tf
#       7
# ----> 8 import dataset.dataset_ops as ops
#       9 import dataset.image_ops as img_ops
#      10
#
# ~\Documents\GitHub\RA2_alpine_lads\dataset\dataset_ops.py in <module>
#       5 import tensorflow as tf
#       6
# ----> 7 import dataset.image_ops as ops
#       8
#       9
#
# ~\Documents\GitHub\RA2_alpine_lads\dataset\image_ops.py in <module>
#       1 import tensorflow as tf
# ----> 2 import tensorflow_addons as tfa
#       3 import numpy as np
#       4 import logging
#       5 import math
#
# ...

# %%
import matplotlib.pyplot as plt

for images, label in landmark_dataset.take(1):
    for idx, image in enumerate(images):
        plt.figure(figsize = (8, 8))
        plt.imshow(image[:, :, 0], cmap="gray")
        plt.scatter(label[idx][0::2], label[idx][1::2], 20, c = 'red', marker = 'x')
        plt.show()

# %%
print(landmarks_dataframe.iloc[:10])
