# %%
import os

PATH = 'C:\\Users\\CrankMuffler\\Documents\\GitHub\\RA2_alpine_lads'

os.chdir(PATH)

# %%
from dataset.landmarks_dataset import get_landmarks_dataset

landmark_dataset = get_landmarks_dataset('./data/landmarks')

# %%
import matplotlib.pyplot as plt

for image, label in landmark_dataset.take(2):
    plt.figure(figsize = (8, 8))
    plt.imshow(image[:, :, 0], cmap="gray")
    plt.scatter(label[0::2], label[1::2], 20, c = 'red', marker = 'x')
    plt.show()
